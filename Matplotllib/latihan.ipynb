# %% [markdown]
# Problem Statement
#
# You have been provided with a dataset that lists Ohio States's leading causes a death from the year 2012.
# Using the two data points cause of *death and percentile*, draw a pie chart to visualize the data.

# %%
#import required libraries
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Data from Ohio State, leading cause of death in the state form year 2012
#cause of deaths
cause = 'Chronic Desease','Unintentional Injuries','Alzheimers','Influenza and Pneumonia','Sepsis','Others'
#percemtile
percentile = [62,5,4,2,1,26]

# %%
#set rhe pie chart plot properties
#set figure size
plt.figure(figsize=(10,10))
#explode the largest pie in the data set
explode = (0.05,0,0,0,0,0)
#set pie chart properties 
plt.pie(percentile, labels=cause,explode=explode,autopct='%1.1f%%',startangle=70)
#set axis equal to draw pie as circle
plt.axis('equal')
#set tittle of the pie chart
plt.title('Ohio State - 2012 : Leading Cause of Death')
#show the plat (pie chart)
plt.show()
