# %%
import pandas as pd

# %%
df = pd.read_csv("PriceHouse.csv",parse_dates = True)

# %%
df.head()
# Out:
#          date    price  bedrooms  bathrooms  sqft_living  sqft_lot  floors
# 0  2022-30-04   313000         3       1.50         1340      7912     1.5  \
# 1  2022-30-04  2384000         5       2.50         3650      9050     2.0
# 2  2022-30-04   342000         3       2.00         1930     11947     1.0
# 3  2022-30-04   420000         3       2.25         2000      8030     1.0
# 4  2022-30-04   550000         4       2.50         1840     10500     1.0
#
#    waterfront  view  condition  sqft_above  sqft_basement  yr_built
# 0           0     0          3        1340              0      1955  \
# 1           0     4          5        3380            280      1921
# 2           0     0          4        1930              0      1966
# 3           0     0          4        1000           1000      1963
# 4           0     0          4        1140            800      1976
#
#    yr_renovate                    street         city  statezip country
# ...

# %%
df.set_index(['city','date'], inplace= True)

# %%
df.index
# Out:
# MultiIndex([('Slitoreline', '2022-30-04'),
#             (    'Seattle', '2022-30-04'),
#             (       'Kent', '2022-30-04'),
#             (   'Beilevue', '2022-30-04'),
#             (    'Redmond', '2022-30-04')],
#            names=['city', 'date'])

# %%
df.loc['Seattle']
# Out:
#               price  bedrooms  bathrooms  sqft_living  sqft_lot  floors
# date
# 2022-30-04  2384000         5        2.5         3650      9050     2.0  \
#
#             waterfront  view  condition  sqft_above  sqft_basement  yr_built
# date
# 2022-30-04           0     4          5        3380            280      1921  \
#
#             yr_renovate           street  statezip country
# date
# 2022-30-04            0  709 W Blaime St  WA 98119     USA

# %%
df.loc['Seattle'].loc['2022-30-04']
# Out:
# price                    2384000
# bedrooms                       5
# bathrooms                    2.5
# sqft_living                 3650
# sqft_lot                    9050
# floors                       2.0
# waterfront                     0
# view                           4
# condition                      5
# sqft_above                  3380
# sqft_basement                280
# yr_built                    1921
# yr_renovate                    0
# street           709 W Blaime St
# statezip                WA 98119
# country                      USA
# Name: 2022-30-04, dtype: object
